# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#                      id  click                 hour    C1  banner_pos  \
# 0  10040991237561473144      0  2014-10-21 00:00:00  1005           1
# 1  10220027634458631292      1  2014-10-21 00:00:00  1005           0
# 2  10353033015277123997      1  2014-10-21 00:00:00  1005           1
# 3  10404559309779615378      1  2014-10-21 00:00:00  1005           0
# 4  10440958171495887897      0  2014-10-21 00:00:00  1005           0
#
#     site_id site_domain site_category    app_id app_domain  ... device_type  \
# 0  43d6df75    27e3c518      28905ebd  ecad2386   7801e8d9  ...           1
# 1  5b08c53b    7687a86e      3e814130  ecad2386   7801e8d9  ...           1
# 2  e151e245    7e091613      f028772b  ecad2386   7801e8d9  ...           1
# 3  1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 4  1fbe01fe    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19  C20  C21
# ...

# %%
# click distribution
df['click'].value_counts().to_dict()
# Out:
# {0: 41641, 1: 8359}

# %%
# count unique per column
df.nunique().to_dict()
# Out:
# {'id': 50000,
#  'click': 2,
#  'hour': 240,
#  'C1': 7,
#  'banner_pos': 7,
#  'site_id': 1132,
#  'site_domain': 996,
#  'site_category': 18,
#  'app_id': 960,
#  'app_domain': 71,
#  'app_category': 20,
#  'device_id': 8481,
#  'device_ip': 41307,
#  'device_model': 2537,
#  'device_type': 4,
#  'device_conn_type': 4,
#  'C14': 1531,
#  'C15': 8,
#  'C16': 9,
#  'C17': 386,
#  'C18': 4,
#  'C19': 63,
#  'C20': 151,
#  'C21': 59}

# %%
# value count of specific column
df['device_conn_type'].value_counts().to_dict()
# Out:
# {0: 43133, 2: 4073, 3: 2740, 5: 54}

# %%
# id vs device_type
df['device_conn_type'].value_counts().to_dict()
# Out:
# {0: 43133, 2: 4073, 3: 2740, 5: 54}

# %%
# heatmap
df.select_dtypes('number').corr().to_dict()
# Out:
# {'id': {'id': 1.0,
#   'click': 6.071210239955467e-05,
#   'C1': 0.006468731052826501,
#   'banner_pos': -0.000523756368585209,
#   'device_type': 0.002816046134128314,
#   'device_conn_type': 0.0003579064009772797,
#   'C14': 0.003475838879509216,
#   'C15': -0.0023768614189073087,
#   'C16': 0.0033093882585267303,
#   'C17': 0.004862858440046158,
#   'C18': -0.0016382264509856854,
#   'C19': -0.003174374762523331,
#   'C20': -0.002052719210800253,
#   'C21': 0.0013107685394733713},
#  'click': {'id': 6.071210239955467e-05,
#   'click': 1.0,
#   'C1': -0.040396742146526596,
#   'banner_pos': 0.02167292055694471,
#   'device_type': -0.041900593837066076,
#   'device_conn_type': -0.08127018722362973,
#   'C14': -0.05302962209923187,
#   'C15': -0.030943082510899413,
#   'C16': 0.1242345733253807,
#   'C17': -0.04897462689490175,
#   'C18': 0.021072844778581287,
#   'C19': -0.00314038801156735,
#   'C20': -0.058598350532849,
#   'C21': -0.06849071171965217},
# ...

# %%
group_data = df.groupby(['banner_pos', 'click']).size().unstack()
group_data['Frequency'] = df['banner_pos'].value_counts(normalize=True)
ctr = group_data[1] / (group_data[0] + group_data[1])
group_data['CTR'] = ctr
group_data = group_data.fillna(0)

# %%
group_data.to_dict()
# Out:
# {0: {0: 30167.0, 1: 11401.0, 2: 17.0, 3: 4.0, 4: 12.0, 5: 5.0, 7: 35.0},
#  1: {0: 5866.0, 1: 2470.0, 2: 3.0, 3: 0.0, 4: 1.0, 5: 3.0, 7: 16.0},
#  'Frequency': {0: 0.72066,
#   1: 0.27742,
#   2: 0.0004,
#   3: 8e-05,
#   4: 0.00026,
#   5: 0.00016,
#   7: 0.00102},
#  'CTR': {0: 0.16279521549690562,
#   1: 0.1780693533270853,
#   2: 0.15,
#   3: 0.0,
#   4: 0.07692307692307693,
#   5: 0.375,
#   7: 0.3137254901960784}}

# %%
device_id_counts = df['device_id'].value_counts()
df['device_id_counts'] = df['device_id'].map(device_id_counts)
# device_IP_counts

# %%
# convert to datetime
df['hour'] = pd.to_datetime(df['hour'])

# %%
df['hour_of_day'] = df['hour'].dt.hour
df['day_of_week'] = df['hour'].dt.dayofweek

# %%
df[['hour', 'click']].groupby('hour').agg({'click': 'sum'}).to_dict()
# Out:
# {'click': {Timestamp('2014-10-21 00:00:00'): 26,
#   Timestamp('2014-10-21 01:00:00'): 37,
#   Timestamp('2014-10-21 02:00:00'): 38,
#   Timestamp('2014-10-21 03:00:00'): 28,
#   Timestamp('2014-10-21 04:00:00'): 52,
#   Timestamp('2014-10-21 05:00:00'): 56,
#   Timestamp('2014-10-21 06:00:00'): 33,
#   Timestamp('2014-10-21 07:00:00'): 39,
#   Timestamp('2014-10-21 08:00:00'): 49,
#   Timestamp('2014-10-21 09:00:00'): 43,
#   Timestamp('2014-10-21 10:00:00'): 42,
#   Timestamp('2014-10-21 11:00:00'): 43,
#   Timestamp('2014-10-21 12:00:00'): 29,
#   Timestamp('2014-10-21 13:00:00'): 44,
#   Timestamp('2014-10-21 14:00:00'): 46,
#   Timestamp('2014-10-21 15:00:00'): 30,
#   Timestamp('2014-10-21 16:00:00'): 38,
#   Timestamp('2014-10-21 17:00:00'): 26,
#   Timestamp('2014-10-21 18:00:00'): 26,
#   Timestamp('2014-10-21 19:00:00'): 28,
#   Timestamp('2014-10-21 20:00:00'): 22,
#   Timestamp('2014-10-21 21:00:00'): 17,
#   Timestamp('2014-10-21 22:00:00'): 16,
# ...

# %%
data = df.describe().to_dict()

# %%
data.keys()
# Out:
# dict_keys(['id', 'click', 'C1', 'banner_pos', 'device_type', 'device_conn_type', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'])

# %%
data.values()
# Out:
# dict_values([{'count': 50000.0, 'mean': 9.188786814924163e+18, 'std': 5.329187056670467e+18, 'min': 799525985517557.0, '25%': 4.6044760784616873e+18, '50%': 9.16836987267742e+18, '75%': 1.3818411887232293e+19, 'max': 1.8446664021796995e+19}, {'count': 50000.0, 'mean': 0.16718, 'std': 0.37314023137775626, 'min': 0.0, '25%': 0.0, '50%': 0.0, '75%': 0.0, 'max': 1.0}, {'count': 50000.0, 'mean': 1004.96334, 'std': 1.0874280180287283, 'min': 1001.0, '25%': 1005.0, '50%': 1005.0, '75%': 1005.0, 'max': 1012.0}, {'count': 50000.0, 'mean': 0.28744, 'std': 0.5052359366345919, 'min': 0.0, '25%': 0.0, '50%': 0.0, '75%': 1.0, 'max': 7.0}, {'count': 50000.0, 'mean': 1.0142, 'std': 0.5266534983061877, 'min': 0.0, '25%': 1.0, '50%': 1.0, '75%': 1.0, 'max': 5.0}, {'count': 50000.0, 'mean': 0.33272, 'std': 0.8575267393161409, 'min': 0.0, '25%': 0.0, '50%': 0.0, '75%': 0.0, 'max': 5.0}, {'count': 50000.0, 'mean': 18894.59866, 'std': 4926.755041100673, 'min': 375.0, '25%': 16920.0, '50%': 20359.0, '75%':
# ...

# %%
df.describe().transpose()
# Out:
#                     count          mean           std           min  \
# id                50000.0  9.188787e+18  5.329187e+18  7.995260e+14
# click             50000.0  1.671800e-01  3.731402e-01  0.000000e+00
# C1                50000.0  1.004963e+03  1.087428e+00  1.001000e+03
# banner_pos        50000.0  2.874400e-01  5.052359e-01  0.000000e+00
# device_type       50000.0  1.014200e+00  5.266535e-01  0.000000e+00
# device_conn_type  50000.0  3.327200e-01  8.575267e-01  0.000000e+00
# C14               50000.0  1.889460e+04  4.926755e+03  3.750000e+02
# C15               50000.0  3.189149e+02  2.174539e+01  1.200000e+02
# C16               50000.0  5.985856e+01  4.676949e+01  2.000000e+01
# C17               50000.0  2.118812e+03  6.057070e+02  1.120000e+02
# C18               50000.0  1.424240e+00  1.324634e+00  0.000000e+00
# C19               50000.0  2.254673e+02  3.491321e+02  3.300000e+01
# C20               50000.0  5.345181e+04  4.994214e+04 -1.000000e+00
# ...

# %%
corr_matrix = df.select_dtypes(include=['number']).corr()

# %%
corr_matrix
# Out:
#                         id     click        C1  banner_pos  device_type  \
# id                1.000000  0.000061  0.006469   -0.000524     0.002816
# click             0.000061  1.000000 -0.040397    0.021673    -0.041901
# C1                0.006469 -0.040397  1.000000    0.289258     0.898224
# banner_pos       -0.000524  0.021673  0.289258    1.000000     0.318847
# device_type       0.002816 -0.041901  0.898224    0.318847     1.000000
# device_conn_type  0.000358 -0.081270  0.192902   -0.089781     0.204281
# C14               0.003476 -0.053030  0.055284   -0.003007     0.044814
# C15              -0.002377 -0.030943  0.134070    0.065695     0.194547
# C16               0.003309  0.124235  0.061259    0.018771     0.064528
# C17               0.004863 -0.048975  0.065140   -0.022389     0.051958
# C18              -0.001638  0.021073 -0.049144    0.088244    -0.054707
# C19              -0.003174 -0.003140  0.003142    0.129447    -0.000210
# ...

# %%
list(corr_matrix.columns)
# Out:
# ['id',
#  'click',
#  'C1',
#  'banner_pos',
#  'device_type',
#  'device_conn_type',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21']

# %%
len(corr_matrix.values.tolist())
# Out:
# 50000
