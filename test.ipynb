# %%
import pandas as pd
from category_encoders import TargetEncoder
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.decomposition import PCA

# %%
X_train = pd.read_csv(r'C:\Sunset\media\upload\users\train_test_data\X_train.csv')
X_test = pd.read_csv(r'C:\Sunset\media\upload\users\train_test_data\X_test.csv')
y_train = pd.read_csv(r'C:\Sunset\media\upload\users\train_test_data\y_test.csv')
y_test = pd.read_csv(r'C:\Sunset\media\upload\users\train_test_data\y_train.csv')

# %%
X_train
# Out:
#        device_ip_ctr  device_id_ctr  site_id_target   C14_ctr  \
# 0           0.000000       0.169982        0.350318  0.117537
# 1           0.500000       1.000000        0.114912  0.166667
# 2           0.000000       0.169982        0.151163  0.142857
# 3           0.000000       0.169982        0.204896  0.195029
# 4           0.666667       0.169982        0.054645  0.095759
# ...              ...            ...             ...       ...
# 39995       0.000000       0.169982        0.459613  0.354839
# 39996       0.000000       0.169982        0.291383  0.263441
# 39997       0.254237       0.169982        0.204896  0.252174
# 39998       0.000000       0.000000        0.114912  0.090164
# 39999       0.000000       0.169982        0.114912  0.017032
#
#        device_id_target         0         1         2         3         4  \
# 0              0.169982 -0.081984  0.635542 -0.882194 -0.801234 -0.016811
# ...

# %%
import pickle
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

with open('C:\Sunset\LogisticRegression.pkl', 'rb') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[60], line 6
#       3 from catboost import CatBoostClassifier
#       5 with open('C:\Sunset\LogisticRegression.pkl', 'rb') as f:
# ----> 6     model = pickle.load(f)
#
# ModuleNotFoundError: No module named 'cuml'

# %%
print(type(model))
# print(model.get_params())
# Out:
# <class 'catboost.core.CatBoostClassifier'>

# %%
y_pred = model.predict_proba(X_test)

# %%
y_pred
# Out:
# array([[0.78720554, 0.21279446],
#        [0.85765573, 0.14234427],
#        [0.78720554, 0.21279446],
#        ...,
#        [0.85765573, 0.14234427],
#        [0.85765573, 0.14234427],
#        [0.78720554, 0.21279446]], shape=(10000, 2))
